# %% [markdown]
# # ModelForge ML - Exploratory Data Analysis
#
# This notebook is a lightweight starting point for inspecting the churn dataset before training.

# %%
from pathlib import Path

import pandas as pd

data_path = Path('../data/raw/churn.csv')
if not data_path.exists():
    data_path = Path('../data/sample/sample_churn.csv')

df = pd.read_csv(data_path)
df.head()

# %%
df.info()

# %%
df['Exited'].value_counts(normalize=True).rename('share')

# %%
df.describe(include='all').T
